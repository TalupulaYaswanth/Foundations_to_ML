# %%
import pandas as pd

# %%
# the low standard deviation give

# %%
# bell curve

# %%
# (+-)3 standard deviation it is the normal range of the
#  the above the range of bell curve is a outlier
# ----------------
# to find the outlier we use the z-score->formula(z=((x-mean)/standard deviation))

# %%
# correlation coefficient(r)==(sumof(x1-x_)*sumof(y1-y_))/(sumof(x1-x_)^2*sumof(y1-y_)^2)^(1/2)

# ---------------------------------
# mcar--->missing co
